# %% [markdown]
# <a href="https://colab.research.google.com/github/AdanALalawni/Data_Visualization/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read Data

# %% [markdown]
# <li>Univariate visualizations: Visualize single-variables, such
# as bar charts, histograms, and line charts.
# <li>Bivariate visualizations: Plots representing the relationship between two variables measured on the given sample data. These plots help to identify the relationship pattern between the two variables.
# <li>Ordinal data: It is a categorical data type where the variables have natural and ordered categories. The distances between the categories are unknown, such as the survey options presented on a five-point scale.

# %%
import pandas as pd
url='/content/sample_data/Iris.csv'
data=pd.read_csv(url)
fule_data = pd.read_csv('/content/sample_data/fuel-econ.csv')
data.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Bar Chart

# %%
sns.countplot(y='Species',data=data , color=sns.color_palette()[1])
plt.show()

# %%
data_species=data.value_counts('Species')
plt.bar(data_species.index ,data_species.values)
for i , value in enumerate(data_species.values):
  plt.text(i,value,str(value),ha='center',va='bottom')
plt.show()

# %%
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Pie chart

# %%
plt.pie(data_species.values,labels=data_species.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7c07a12fd030>,
# ...
#  [Text(0.5499999702695115, 0.9526279613277875, 'Iris-setosa'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'Iris-versicolor'),
#   Text(0.5500001486524352, -0.9526278583383436, 'Iris-virginica')])

# %% [markdown]
# # Histograms

# %%
import numpy as np

# %%
bin=np.arange(4, max(data['SepalLengthCm'])+0.5 ,0.5)
plt.hist(data['SepalLengthCm'],bins=bin )
# Out:
# (array([ 4., 18., 30., 31., 32., 22.,  7.,  6.]),
#  array([4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 8 artists>)

# %%
sns.distplot(data['SepalLengthCm'] ,bins=bin)
# Out:
# <ipython-input-9-342fd1fe2df5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['SepalLengthCm'] ,bins=bin)
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.hist(data['SepalLengthCm'],bins=bin )
plt.subplot(1,2,2)
sns.distplot(data['SepalLengthCm'] ,bins=bin)
plt.show()
# Out:
# <ipython-input-10-576c88bd62ff>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['SepalLengthCm'] ,bins=bin)

# %% [markdown]
# #  Scatterplot

# %% [markdown]
# used to measure pearson correlation coefficient between two vars
# ![image.png](data:image/png;base64,...)

# %%
plt.scatter(data=data , y='SepalWidthCm',x='SepalLengthCm')
plt.xlabel('SepalLengthCm')
plt.ylabel('SepalWidthCm')
plt.title('SepalLengthCm vs SepalWidthCm')
plt.show()

# %%
sns.regplot(data=data , y='SepalWidthCm',x='SepalLengthCm')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.regplot(data=fule_data , y='comb',x='year' , x_jitter=0.3,scatter_kws={'alpha':1/20})
# Out:
# <Axes: xlabel='year', ylabel='comb'>

# %% [markdown]
# # Heat Map

# %%
plt.hist2d(data = fule_data, x = 'displ', y = 'comb', cmin=0.5, cmap='viridis_r')
plt.colorbar()
plt.xlabel('Displacement (1)')
plt.ylabel('Combined Fuel Eff. (mpg)');

# %% [markdown]
# # Violin Plot

# %%
fule_data.head()
# Out:
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
#
#                drive              trans          fuelType  cylinders  displ  \
# 0    All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# 1  Front-Wheel Drive  Automatic (AM-S6)  Premium Gasoline          4    2.0
# 2  Front-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 3    All-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 4  Front-Wheel Drive     Automatic (S6)  Regular Gasoline          4    2.4
#
#    pv2  pv4     city    UCity  highway  UHighway     comb  co2  feScore  \
# ...

# %%
plt.figure(figsize=(10,5))
sns.violinplot(data=fule_data , x='VClass' , y='comb')
plt.show()

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(data=fule_data , x='VClass' , y='comb')
# Out:
# <Axes: xlabel='VClass', ylabel='comb'>

# %%
plt.figure(figsize=(25,10))
plt.subplot(1,2,1)
sns.boxplot(data=fule_data , x='VClass' , y='comb')
plt.subplot(1,2,2)
sns.violinplot(data=fule_data , x='VClass' , y='comb' , inner='quartile' )
plt.show()

# %% [markdown]
# # Clustered Bar

# %%
fule_data['trans_type'] = fule_data['trans'].apply(lambda x: x.split()[0])

# %%
sns.countplot(data=fule_data , hue='trans_type' , x='VClass')
# Out:
# <Axes: xlabel='VClass', ylabel='count'>

# %%
ct_class=fule_data.groupby(['VClass','trans_type']).size().reset_index(name='count')
print(ct_class)
# Out:
#              VClass trans_type  count
# 0      Compact Cars  Automatic    784
# 1      Compact Cars     Manual    338
# 2        Large Cars  Automatic    605
# 3        Large Cars     Manual     20
# 4      Midsize Cars  Automatic    989
# 5      Midsize Cars     Manual    199
# 6  Minicompact Cars  Automatic    188
# 7  Minicompact Cars     Manual    133
# 8   Subcompact Cars  Automatic    502
# 9   Subcompact Cars     Manual    171

# %%
sns.heatmap(ct_class.pivot(index='VClass',columns='trans_type',values='count'),annot=True , fmt='d')
# Out:
# <Axes: xlabel='trans_type', ylabel='VClass'>

# %% [markdown]
# # Faceting

# %%
sns.FacetGrid(data=data , col='Species').map(plt.scatter , 'SepalLengthCm' , 'SepalWidthCm')

# %%
bin =np.arange(12,58+2,2)
sns.FacetGrid(data=fule_data , col='VClass' , col_wrap=3).map(plt.hist , 'comb' , bins=bin)

# %% [markdown]
# # Adaptation of Univariate Plots

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.barplot(data=fule_data , x='VClass' , y='comb')
plt.subplot(1,3,2)
sns.boxplot(data=fule_data , x='VClass' , y='comb')
plt.subplot(1,3,3)
sns.pointplot(data=fule_data , x='VClass' , y='comb')
plt.show()
